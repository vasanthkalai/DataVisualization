# %%
#importing libraries
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %%
#importing dataframe
df=pd.read_excel("obama-approval-ratings.xls")

# %%
df.head()
# Out:
#              Issue  Approve  Disapprove  None
# 0   Race Relations       52          38    10
# 1        Education       49          40    11
# 2        Terrorism       48          45     7
# 3    Energy Policy       47          42    11
# 4  Foreign Affairs       44          48     8

# %% [markdown]
# ### 1. Bar plot

# %%
df.plot.bar(x="Issue",y="Approve", title="Issues Approval count",xlabel="Issues",ylabel="Approval Count",figsize=(12,8))
# Out:
# <AxesSubplot:title={'center':'Issues Approval count'}, xlabel='Issues', ylabel='Approval Count'>

# %% [markdown]
# ### 2. Stacked Bar Plot

# %%
df.plot.bar(x="Issue",title="Obama Approve-Disapprove Stauts",xlabel="Issues",ylabel="Count",figsize=(12,8))
# Out:
# <AxesSubplot:title={'center':'Obama Approve-Disapprove Stauts'}, xlabel='Issues', ylabel='Count'>

# %% [markdown]
# ### 3. Pie Plot

# %%
plt.figure(figsize=(12,8))
plt.pie(df['Approve'],labels=df['Issue'],autopct='%1.1f%%')
plt.title('Approval Status')
plt.show()

# %% [markdown]
# ### 4. Donut Plot

# %%
plt.figure(figsize=(12,8))
#Creating sum 
total=[sum(df['Approve']),sum(df['Disapprove']),sum(df['None'])]

#labels
labels=['Approve','Disapprove','None']

#coloe
colors=['#ADFF2F', '#FF0000', '#FFFF00']

#explosion
explode=(0.05,0.05,0.05)

# Pie Chart
plt.pie(total, colors=colors, labels=labels,
        autopct='%1.1f%%', pctdistance=0.85,
        explode=explode)
  
# draw circle
centre_circle = plt.Circle((0, 0), 0.70, fc='white')
fig = plt.gcf()
  
# Adding Circle in Pie chart
fig.gca().add_artist(centre_circle)
  
# Adding Title of chart
plt.title('Obama Approval Status')
  
# Add Legends
plt.legend(labels, loc="upper right", title="Status")
  
# Displaing Chart
plt.show()
